# %% [markdown]
# ---
# # Model S - From Scratch, RMSProp
# - 32 x 32 x 3 Image size.
# - **64 Batch size**.
# - Root Mean Square Propagation **(RMSProp) optimizer**.
# - **0.001 Initial Learning rate**.
# - 3 x 3 Convolutional kernel size.
# - 5 x 5 x 128 Tensor before flatten.
# - **40 Epochs**.

# %% [markdown]
# ---
# #### Imports and Setup

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
print(f'TensorFlow version: {tf.__version__}')
tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(3)
import matplotlib.pyplot as plt
import pickle
import numpy as np
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow import keras
from tensorflow.keras import callbacks, layers, optimizers, models
from keras import regularizers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay ,accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
# Out:
# TensorFlow version: 2.12.0

# %% [markdown]
# ---
# #### Group Datasets

# %%
train_dirs = ['../data/train1', '../data/train3', '../data/train4', '../data/train5']
validation_dir = '../data/train2'
test_dir = '../data/test'

# %% [markdown]
# - ((2221985 + 2221986) % 5) + 1 = 2
# - **Validation set: train2**.

# %% [markdown]
# ---
# ####  Count Images in Categories

# %%
def count_images_in_categories(directory):
    categories = os.listdir(directory)
    category_counts = {}
    for category in categories:
        category_counts[category] = len(os.listdir(os.path.join(directory, category)))
    return category_counts

train_counts_each_dir = [count_images_in_categories(train_dir) for train_dir in train_dirs]
validation_counts = count_images_in_categories(validation_dir)
test_counts = count_images_in_categories(test_dir)
train_counts = {category: sum([count.get(category, 0) for count in train_counts_each_dir]) for category in train_counts_each_dir[0]}

def plot_statistics(dataset_name, category_counts, color):
    categories = list(category_counts.keys())
    counts = list(category_counts.values())
    num_categories = len(categories)
    plt.figure(figsize=(8, 6))
    bars = plt.barh(range(num_categories), counts, color=color, alpha=1)

    for bar, count in zip(bars, counts):
        plt.text(bar.get_width() - 5, bar.get_y() + bar.get_height()/2, str(count), va='center', ha='right', color='white', fontweight='bold')
        
    plt.ylabel('Categories')
    plt.xlabel('Number of Images')
    plt.yticks(range(num_categories), categories)
    plt.title(f'Distribution of Images in {dataset_name} Dataset')
    plt.tight_layout()
    plt.show()

plot_statistics('Training Set', train_counts, 'blue')
plot_statistics('Validation Set', validation_counts, 'purple')
plot_statistics('Test Set', test_counts, 'red')

# %% [markdown]
# - We count the images of each category in each folder and plot the distribution.
# - We see that there are **minor deviations** the number of samples of each category in the train dataset and a bit **more in the validation dataset**.

# %% [markdown]
# ---
# #### Create Datasets

# %%
IMG_SIZE = 32
BATCH_SIZE = 64
NUM_CLASSES = len(train_counts)

train_datasets = [image_dataset_from_directory(directory, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE) for directory in train_dirs]

train_dataset = train_datasets[0]
for dataset in train_datasets[1:]:
    train_dataset = train_dataset.concatenate(dataset)

train_dataset = train_dataset.shuffle(buffer_size=1000).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_dataset = image_dataset_from_directory(validation_dir, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset = image_dataset_from_directory(test_dir, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)

class_names = train_datasets[0].class_names
# Out:
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.

# %% [markdown]
# - We define the image size of 32 x 32 x 3 and batch size of 64 and create an array with the label's names.
# - We create the train dataset by concatenating them, we **shuffle** the samples before each epoch and **prefetch** them to memory.
# - We do the same for the validation and test dataset except shuffling which is unnecessary.

# %% [markdown]
# ---
# #### Dataset Analysis

# %%
for data_batch, labels_batch in train_dataset.take(1):
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
# Out:
# data batch shape: (64, 32, 32, 3)
# labels batch shape: (64,)

# %% [markdown]
# - We have batches of 64 images, 32 by 32 pixels with 3 channels (RGB).
# - We also have batches of 64 labels, one for each image.

# %% [markdown]
# ---
# #### Dataset Visualization

# %%
for images, labels in train_dataset.take(1):
    plt.figure(figsize=(32, 32))
    for i in range(len(images)):
        ax = plt.subplot(8, 8, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i].numpy()])
        plt.axis("off")
        plt.tight_layout()
    plt.show()

# %% [markdown]
# - We print a random batch of images from the train dataset along with their respective labels.
# - We see that the images are of **different categories** and are of **low resolution**.

# %% [markdown]
# ---
# #### Model Architecture

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=16, kernel_size=3, kernel_regularizer=regularizers.L1L2(0.00001, 0.0001), activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(filters=32, kernel_size=3, kernel_regularizer=regularizers.L1L2(0.00001, 0.0001), activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, kernel_regularizer=regularizers.L1L2(0.00001, 0.0001), activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(filters=128, kernel_size=3, kernel_regularizer=regularizers.L1L2(0.00001, 0.0001), activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(256, activation="relu", kernel_regularizer=regularizers.L1L2(0.0001, 0.001))(x)
x = layers.Dropout(0.125)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax", kernel_regularizer=regularizers.L1L2(0.0001, 0.001))(x)
model = models.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  rescaling (Rescaling)       (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 30, 30, 16)        448
#
#  batch_normalization (BatchN  (None, 30, 30, 16)       64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        4640
#
#  batch_normalization_1 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 12, 12, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 10, 10, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 3200)              0
#
#  dropout (Dropout)           (None, 3200)              0
#
#  dense (Dense)               (None, 256)               819456
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 920,426
# Trainable params: 919,946
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# - Input size of 32 x 32 x 3 (RGB).
# - No data augmentation.
# - Normalize each pixel value in the [0, 1] interval.
# - Two convolutional layers (16 and 32 kernels each respectively).
# - Max pooling with size 2 after the second convolution results in a 14 x 14 x 32 tensor.
# - Two convolutional layers (64 and 128 kernels each respectively).
# - Max pooling with size 2 after the fourth convolution results in a 5 x 5 x 128 tensor.
# - 3 x 3 convolutional kernel size.
# - Batch Normalization after each convolutional layer to help stabilize and accelerate learning process.
# - L1 regularization 0.00001 and L2 regularization 0.0001 on the convolutional layers.
# - Flatten the tensor to a 3200 x 1 tensor.
# - A 256 and 10 dense output layer, one for each category.
# - L1 regularization 0.0001 and L2 regularization 0.001 on the 256 and 10 dense layer.
# - Dropout of 0.5 after the flatten layer and 0.125 after the 256 dense layer.
# - ReLU activation function on the convolutional and dense layers.
# - Softmax activation function on the output layer from multiclass classification.

# %% [markdown]
# ---
# #### Model Compilation

# %%
initial_learning_rate = 0.001
optimizer = optimizers.RMSprop(learning_rate=initial_learning_rate)
loss_function = keras.losses.SparseCategoricalCrossentropy()

lr_scheduler = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1)
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True, verbose=1)
save_best_model = callbacks.ModelCheckpoint(filepath='../models/01_model_s_rmsprop.h5', save_best_only=True, monitor='val_loss', verbose=1)

callbacks = [lr_scheduler, early_stopping, save_best_model]

model.compile(optimizer=optimizer,
              loss=loss_function,
              metrics=['accuracy'])

# %% [markdown]
# - RMSProp as the optimizer for this model with an initial learning rate of 0.001.
# - Sparse categorical cross entropy as the loss function, because our labels are not one hot encoded.
# - Learning rate scheduler to lower the learning rate by 0.1 on validation loss plateau (patience of 2).
# - Early train stopping based on validation loss improvement (stops when validation loss doesn't improve for 4 straight epochs (patience of 4)).
# - Checkpoints to save the best model between each epoch based on validation loss.

# %% [markdown]
# ---
# #### Model Training
# - Training the model during 40 epochs.

# %%
history = model.fit(train_dataset,
                    validation_data=validation_dataset,
                    epochs=40,
                    callbacks=callbacks)
# Out:
# Epoch 1/40
# 627/628 [============================>.] - ETA: 0s - loss: 2.8808 - accuracy: 0.4861
# Epoch 1: val_loss improved from inf to 2.01568, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 23s 34ms/step - loss: 2.8798 - accuracy: 0.4861 - val_loss: 2.0157 - val_accuracy: 0.6103 - lr: 0.0010
# Epoch 2/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.8318 - accuracy: 0.6371
# Epoch 2: val_loss improved from 2.01568 to 1.63422, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 1.8315 - accuracy: 0.6371 - val_loss: 1.6342 - val_accuracy: 0.6935 - lr: 0.0010
# Epoch 3/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.5758 - accuracy: 0.6901
# Epoch 3: val_loss improved from 1.63422 to 1.54470, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 1.5755 - accuracy: 0.6901 - val_loss: 1.5447 - val_accuracy: 0.6907 - lr: 0.0010
# Epoch 4/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.4626 - accuracy: 0.7182
# Epoch 4: val_loss did not improve from 1.54470
# 628/628 [==============================] - 21s 33ms/step - loss: 1.4628 - accuracy: 0.7182 - val_loss: 1.5778 - val_accuracy: 0.6726 - lr: 0.0010
# Epoch 5/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.3929 - accuracy: 0.7342
# Epoch 5: val_loss improved from 1.54470 to 1.37659, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 1.3927 - accuracy: 0.7342 - val_loss: 1.3766 - val_accuracy: 0.7358 - lr: 0.0010
# Epoch 6/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.3442 - accuracy: 0.7474
# Epoch 6: val_loss improved from 1.37659 to 1.37074, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 1.3442 - accuracy: 0.7473 - val_loss: 1.3707 - val_accuracy: 0.7411 - lr: 0.0010
# Epoch 7/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.3105 - accuracy: 0.7627
# Epoch 7: val_loss improved from 1.37074 to 1.36334, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 1.3105 - accuracy: 0.7627 - val_loss: 1.3633 - val_accuracy: 0.7420 - lr: 0.0010
# Epoch 8/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.2831 - accuracy: 0.7695
# Epoch 8: val_loss did not improve from 1.36334
# 628/628 [==============================] - 21s 32ms/step - loss: 1.2829 - accuracy: 0.7697 - val_loss: 1.3936 - val_accuracy: 0.7328 - lr: 0.0010
# Epoch 9/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.2548 - accuracy: 0.7796
# Epoch 9: val_loss improved from 1.36334 to 1.30627, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 32ms/step - loss: 1.2548 - accuracy: 0.7796 - val_loss: 1.3063 - val_accuracy: 0.7604 - lr: 0.0010
# Epoch 10/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.2379 - accuracy: 0.7852
# Epoch 10: val_loss did not improve from 1.30627
# 628/628 [==============================] - 21s 32ms/step - loss: 1.2377 - accuracy: 0.7852 - val_loss: 1.6082 - val_accuracy: 0.6845 - lr: 0.0010
# Epoch 11/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.2181 - accuracy: 0.7902
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 11: val_loss did not improve from 1.30627
# 628/628 [==============================] - 21s 32ms/step - loss: 1.2178 - accuracy: 0.7903 - val_loss: 1.3566 - val_accuracy: 0.7487 - lr: 0.0010
# Epoch 12/40
# 627/628 [============================>.] - ETA: 0s - loss: 1.0245 - accuracy: 0.8409
# Epoch 12: val_loss improved from 1.30627 to 1.08669, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 32ms/step - loss: 1.0243 - accuracy: 0.8410 - val_loss: 1.0867 - val_accuracy: 0.8116 - lr: 1.0000e-04
# Epoch 13/40
# 626/628 [============================>.] - ETA: 0s - loss: 0.9120 - accuracy: 0.8595
# Epoch 13: val_loss improved from 1.08669 to 1.02564, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 32ms/step - loss: 0.9122 - accuracy: 0.8594 - val_loss: 1.0256 - val_accuracy: 0.8140 - lr: 1.0000e-04
# Epoch 14/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.8567 - accuracy: 0.8628
# Epoch 14: val_loss improved from 1.02564 to 0.98343, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 0.8567 - accuracy: 0.8628 - val_loss: 0.9834 - val_accuracy: 0.8166 - lr: 1.0000e-04
# Epoch 15/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.8120 - accuracy: 0.8683
# Epoch 15: val_loss improved from 0.98343 to 0.95237, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 0.8122 - accuracy: 0.8682 - val_loss: 0.9524 - val_accuracy: 0.8155 - lr: 1.0000e-04
# Epoch 16/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.7765 - accuracy: 0.8739
# Epoch 16: val_loss improved from 0.95237 to 0.92550, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 0.7764 - accuracy: 0.8740 - val_loss: 0.9255 - val_accuracy: 0.8195 - lr: 1.0000e-04
# Epoch 17/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.7451 - accuracy: 0.8766
# Epoch 17: val_loss improved from 0.92550 to 0.91883, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 34ms/step - loss: 0.7455 - accuracy: 0.8764 - val_loss: 0.9188 - val_accuracy: 0.8189 - lr: 1.0000e-04
# Epoch 18/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.7274 - accuracy: 0.8778
# Epoch 18: val_loss improved from 0.91883 to 0.90013, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 22s 34ms/step - loss: 0.7273 - accuracy: 0.8779 - val_loss: 0.9001 - val_accuracy: 0.8198 - lr: 1.0000e-04
# Epoch 19/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.7043 - accuracy: 0.8831
# Epoch 19: val_loss improved from 0.90013 to 0.88728, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 0.7043 - accuracy: 0.8831 - val_loss: 0.8873 - val_accuracy: 0.8210 - lr: 1.0000e-04
# Epoch 20/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.6902 - accuracy: 0.8859
# Epoch 20: val_loss improved from 0.88728 to 0.87857, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 0.6903 - accuracy: 0.8857 - val_loss: 0.8786 - val_accuracy: 0.8201 - lr: 1.0000e-04
# Epoch 21/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.6780 - accuracy: 0.8859
# Epoch 21: val_loss improved from 0.87857 to 0.87283, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 0.6783 - accuracy: 0.8857 - val_loss: 0.8728 - val_accuracy: 0.8195 - lr: 1.0000e-04
# Epoch 22/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.6635 - accuracy: 0.8882
# Epoch 22: val_loss improved from 0.87283 to 0.87027, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 22s 35ms/step - loss: 0.6634 - accuracy: 0.8882 - val_loss: 0.8703 - val_accuracy: 0.8218 - lr: 1.0000e-04
# Epoch 23/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.6493 - accuracy: 0.8930
# Epoch 23: val_loss improved from 0.87027 to 0.86386, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 0.6492 - accuracy: 0.8930 - val_loss: 0.8639 - val_accuracy: 0.8226 - lr: 1.0000e-04
# Epoch 24/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.6393 - accuracy: 0.8946
# Epoch 24: val_loss improved from 0.86386 to 0.86227, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 33ms/step - loss: 0.6394 - accuracy: 0.8946 - val_loss: 0.8623 - val_accuracy: 0.8213 - lr: 1.0000e-04
# Epoch 25/40
# 628/628 [==============================] - ETA: 0s - loss: 0.6333 - accuracy: 0.8962
# Epoch 25: val_loss improved from 0.86227 to 0.85913, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 23s 37ms/step - loss: 0.6333 - accuracy: 0.8962 - val_loss: 0.8591 - val_accuracy: 0.8232 - lr: 1.0000e-04
# Epoch 26/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.6220 - accuracy: 0.8976
# Epoch 26: val_loss did not improve from 0.85913
# 628/628 [==============================] - 21s 33ms/step - loss: 0.6219 - accuracy: 0.8976 - val_loss: 0.8642 - val_accuracy: 0.8221 - lr: 1.0000e-04
# Epoch 27/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.6161 - accuracy: 0.8991
# Epoch 27: val_loss improved from 0.85913 to 0.85619, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 24s 38ms/step - loss: 0.6160 - accuracy: 0.8992 - val_loss: 0.8562 - val_accuracy: 0.8230 - lr: 1.0000e-04
# Epoch 28/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.6073 - accuracy: 0.9014
# Epoch 28: val_loss did not improve from 0.85619
# 628/628 [==============================] - 22s 34ms/step - loss: 0.6072 - accuracy: 0.9014 - val_loss: 0.8580 - val_accuracy: 0.8231 - lr: 1.0000e-04
# Epoch 29/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5995 - accuracy: 0.9029
# Epoch 29: val_loss improved from 0.85619 to 0.85275, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 22s 34ms/step - loss: 0.5996 - accuracy: 0.9029 - val_loss: 0.8528 - val_accuracy: 0.8201 - lr: 1.0000e-04
# Epoch 30/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5986 - accuracy: 0.9032
# Epoch 30: val_loss improved from 0.85275 to 0.85083, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 25s 39ms/step - loss: 0.5986 - accuracy: 0.9032 - val_loss: 0.8508 - val_accuracy: 0.8213 - lr: 1.0000e-04
# Epoch 31/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5888 - accuracy: 0.9068
# Epoch 31: val_loss did not improve from 0.85083
# 628/628 [==============================] - 22s 34ms/step - loss: 0.5889 - accuracy: 0.9068 - val_loss: 0.8549 - val_accuracy: 0.8215 - lr: 1.0000e-04
# Epoch 32/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5819 - accuracy: 0.9090
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 32: val_loss did not improve from 0.85083
# 628/628 [==============================] - 26s 41ms/step - loss: 0.5819 - accuracy: 0.9090 - val_loss: 0.8579 - val_accuracy: 0.8202 - lr: 1.0000e-04
# Epoch 33/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5569 - accuracy: 0.9174
# Epoch 33: val_loss improved from 0.85083 to 0.84807, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 22s 34ms/step - loss: 0.5570 - accuracy: 0.9174 - val_loss: 0.8481 - val_accuracy: 0.8256 - lr: 1.0000e-05
# Epoch 34/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5485 - accuracy: 0.9198
# Epoch 34: val_loss improved from 0.84807 to 0.84261, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 34ms/step - loss: 0.5487 - accuracy: 0.9197 - val_loss: 0.8426 - val_accuracy: 0.8244 - lr: 1.0000e-05
# Epoch 35/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5466 - accuracy: 0.9198
# Epoch 35: val_loss improved from 0.84261 to 0.84130, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 23s 36ms/step - loss: 0.5466 - accuracy: 0.9198 - val_loss: 0.8413 - val_accuracy: 0.8247 - lr: 1.0000e-05
# Epoch 36/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5410 - accuracy: 0.9226
# Epoch 36: val_loss improved from 0.84130 to 0.83846, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 22s 34ms/step - loss: 0.5413 - accuracy: 0.9226 - val_loss: 0.8385 - val_accuracy: 0.8239 - lr: 1.0000e-05
# Epoch 37/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5365 - accuracy: 0.9230
# Epoch 37: val_loss did not improve from 0.83846
# 628/628 [==============================] - 21s 33ms/step - loss: 0.5366 - accuracy: 0.9229 - val_loss: 0.8387 - val_accuracy: 0.8242 - lr: 1.0000e-05
# Epoch 38/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5355 - accuracy: 0.9219
# Epoch 38: val_loss improved from 0.83846 to 0.83555, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 34ms/step - loss: 0.5355 - accuracy: 0.9220 - val_loss: 0.8355 - val_accuracy: 0.8253 - lr: 1.0000e-05
# Epoch 39/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5305 - accuracy: 0.9230
# Epoch 39: val_loss improved from 0.83555 to 0.83525, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 22s 34ms/step - loss: 0.5305 - accuracy: 0.9230 - val_loss: 0.8352 - val_accuracy: 0.8250 - lr: 1.0000e-05
# Epoch 40/40
# 627/628 [============================>.] - ETA: 0s - loss: 0.5313 - accuracy: 0.9221
# Epoch 40: val_loss improved from 0.83525 to 0.83194, saving model to ../models/01_model_s_rmsprop.h5
# 628/628 [==============================] - 21s 34ms/step - loss: 0.5314 - accuracy: 0.9220 - val_loss: 0.8319 - val_accuracy: 0.8261 - lr: 1.0000e-05

# %% [markdown]
# ---
# #### Save Model History

# %%
with open("../history/01_model_s_rmsprop.pkl", "wb") as file:
    pickle.dump(history.history, file)

# %% [markdown]
# ---
# #### Model Evaluation

# %%
val_loss, val_acc = model.evaluate(validation_dataset)
print(f'Model Validation Loss: {val_loss:.2%}')
print(f'Model Validation Accuracy: {val_acc:.2%}')
# Out:
# 157/157 [==============================] - 1s 7ms/step - loss: 0.8319 - accuracy: 0.8261
# Model Validation Loss: 83.19%
# Model Validation Accuracy: 82.61%

# %% [markdown]
# ---
# #### Model Training Visualization

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# - We see that the model begins overfitting after the 13th epoch.
# - The validation accuracy stops improving significantly after the 13th epoch while the training accuracy keeps improving.
# - The validation loss stops improving significantly after the 19th epoch while the training loss keeps improving.
# - The validation loss keeps improving throughout the training despite the small improvements.
# - However, the best model is saved on the 40th epoch.

# %% [markdown]
# ---
# #### Model Testing

# %%
test_labels = []
test_predictions = []
test_probabilities = []

for images, labels in test_dataset:
    test_labels.extend(labels.numpy())
    predictions = model.predict(images)
    test_predictions.extend(np.argmax(predictions, axis=-1))
    test_probabilities.extend(predictions)

test_labels = np.array(test_labels)
test_predictions = np.array(test_predictions)
test_probabilities = np.array(test_probabilities)
# Out:
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 69ms/step

# %% [markdown]
# ---
# #### Confusion Matrix

# %%
cm = confusion_matrix(test_labels, test_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, xticks_rotation=90)
plt.show()

# %% [markdown]
# - Looking at the confusion matrix, we see that the model has some trouble distinguishing between some categories.
# - The model has a hard time distinguishing between the categories 003_cat and 005_dog.
# - Ther model has a hard time distinguishing the categories 002_bird.
# - The model also has a hard time distinguishing between some other categories but the error is not as significant.
# - The model has an acceptable performance on the categories 001_automobile, 006_frog, 008_ship and 009_truck.

# %% [markdown]
# ---
# #### ROC Curve Analysis

# %%
test_labels_bin = label_binarize(test_labels, classes=range(NUM_CLASSES))

false_positive_rate = dict()
true_positive_rate = dict()
roc_auc = dict()

for i in range(NUM_CLASSES):
    false_positive_rate[i], true_positive_rate[i], _ = roc_curve(test_labels_bin[:, i], test_probabilities[:, i])
    roc_auc[i] = auc(false_positive_rate[i], true_positive_rate[i])

plt.figure(figsize=(10, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'blue', 'green', 'red', 'purple', 'brown', 'pink', 'grey'])
for i, color in zip(range(NUM_CLASSES), colors):
    plt.plot(false_positive_rate[i], true_positive_rate[i], color=color, lw=2, label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# - **A perfect AUC of 1.0 would mean that the model classifies all true positives and true negatives correctly**.
# - We see that the model has a good performance on the ROC curve for most categories.
# - The categories 003_cat, 002_bird, 005_dog and 004_deer have the worst AUC (Area Under Curve) performance.

# %% [markdown]
# ---
# #### Performance Metrics
# - **Accuracy** is the proportion of correctly predicted instances out of the total instances.
# - **Precision** is the ratio of true positive predictions to the total predicted positives. Macro precision calculates this for each class independently and then averages them.
# - **Weighted precision** calculates the precision for each class, then averages them, weighted by the number of true instances for each class.
# - **Recall** is the ratio of true positive predictions to the total actual positives. Macro recall calculates this for each class independently and then averages them.
# - **Weighted recall** calculates the recall for each class, then averages them, weighted by the number of true instances for each class.
# - The **F1-score** is the harmonic mean of precision and recall. Macro F1-score calculates this for each class independently and then averages them.
# - **Weighted F1-score** calculates the F1-score for each class, then averages them, weighted by the number of true instances for each class.

# %%
acc = accuracy_score(y_true =  test_labels, y_pred = test_predictions)
print(f'Accuracy : {np.round(acc*100,2)}%')
precision = precision_score(y_true =  test_labels, y_pred = test_predictions, average='macro')
print(f'Precision - Macro: {np.round(precision*100,2)}%')
recall = recall_score(y_true =  test_labels, y_pred = test_predictions, average='macro')
print(f'Recall - Macro: {np.round(recall*100,2)}%')
f1 = f1_score(y_true =  test_labels, y_pred = test_predictions, average='macro')
print(f'F1-score - Macro: {np.round(f1*100,2)}%')
precision = precision_score(y_true =  test_labels, y_pred = test_predictions, average='weighted')
print(f'Precision - Weighted: {np.round(precision*100,2)}%')
recall = recall_score(y_true =  test_labels, y_pred = test_predictions, average='weighted')
print(f'Recall - Weighted: {np.round(recall*100,2)}%')
f1 = f1_score(y_true =  test_labels, y_pred = test_predictions, average='weighted')
print(f'F1-score - Weighted: {np.round(f1*100,2)}%')
# Out:
# Accuracy : 82.83%
# Precision - Macro: 82.82%
# Recall - Macro: 82.83%
# F1-score - Macro: 82.81%
# Precision - Weighted: 82.82%
# Recall - Weighted: 82.83%
# F1-score - Weighted: 82.81%

# %% [markdown]
# - **Since the dataset is balanced, the **MACRO** average is a good metric to evaluate the model.**

# %% [markdown]
# # Conclusion
# - We have trained a model with no data augmentation, using the Sparse Categorical Cross-Entropy loss function and the RMSProp optimizer.
# - We experimented with various architectures, and we settled for the simplicity of this one:
#     - Different learning rates were tested; we settled for the Reduce Learning Rate on Plateau callback.
#     - Various batch sizes were explored; this size was optimal for this architecture.
#     - Multiple optimizers were evaluated; we settled for RMSProp as it was the most effective.
#     - Several regularization values were tried; these values worked best.
#     - Different dropout rates were assessed; this rate provided the best results.
#     - Various epoch counts were tested; 40 epochs were optimal.
#     - Different kernel sizes were considered; this size was most effective.
#     - Various numbers of kernels were tested; this configuration was a combination of simple and effective.
#     - Different numbers of layers were evaluated; this architecture was optimal.
# - We opted to add Batch Normalization after each convolutional layer.
# - We used L1 and L2 regularization on both convolutional and dense layers.
# - Dropout was applied to the dense layers.
# - The model showed some difficulty distinguishing between certain categories, particularly cats and dogs.
# - Overfitting was observed after 13 epochs, but the best model was saved at the 40th epoch.
# - We evaluated the model using a confusion matrix to analyze its performance on each category.
# - We evaluated the model using ROC curves for a deeper performance analysis.
# - The model achieved an accuracy of 82.83% on the test set.
# - Performance on the test set was good, with:
#     - Macro F1-score: 82.81%
#     - Weighted F1-score: 82.81%
#     - Macro precision: 82.82%
#     - Weighted precision: 82.82%
#     - Macro recall: 82.83%
#     - Weighted recall: 82.83%
#
# ### Future Work
# - In the next phase, we will:
#     - Implement and test various data augmentation techniques to further improve model generalization.
#     - For the next notebook, we will experiment with a slightly more complex architecture to test data augmentation techniques.
