# %% [markdown]
# ---
# # Model S - From Scratch, Data Augmentation, Adam Optimizer
# - 32 x 32 x 3 Image size.
# - **64 Batch size**.
# - Horizontal Flip, Contrast and Brightness **Data augmentation**.
# - Adaptive Moment Estimation **(Adam) optimizer**.
# - **0.001 Initial Learning rate**.
# - 3 x 3 Convolutional kernel size.
# - 5 x 5 x 256 Tensor before flatten.
# - **40 Epochs**.

# %% [markdown]
# ---
# #### Imports and Setup

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import tensorflow as tf
print(f'TensorFlow version: {tf.__version__}')
tf.get_logger().setLevel('ERROR')
tf.autograph.set_verbosity(3)
import matplotlib.pyplot as plt
import pickle
import numpy as np
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow import keras
from tensorflow.keras import callbacks, layers, optimizers, models
from keras import regularizers
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay ,accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
# Out:
# TensorFlow version: 2.12.0

# %% [markdown]
# ---
# #### Group Datasets

# %%
train_dirs = ['../data/train1', '../data/train3', '../data/train4', '../data/train5']
validation_dir = '../data/train2'
test_dir = '../data/test'

# %% [markdown]
# - ((2221985 + 2221986) % 5) + 1 = 2
# - **Validation set: train2**.

# %% [markdown]
# ---
# ####  Count Images in Categories

# %%
def count_images_in_categories(directory):
    categories = os.listdir(directory)
    category_counts = {}
    for category in categories:
        category_counts[category] = len(os.listdir(os.path.join(directory, category)))
    return category_counts

train_counts_each_dir = [count_images_in_categories(train_dir) for train_dir in train_dirs]
validation_counts = count_images_in_categories(validation_dir)
test_counts = count_images_in_categories(test_dir)
train_counts = {category: sum([count.get(category, 0) for count in train_counts_each_dir]) for category in train_counts_each_dir[0]}

def plot_statistics(dataset_name, category_counts, color):
    categories = list(category_counts.keys())
    counts = list(category_counts.values())
    num_categories = len(categories)
    plt.figure(figsize=(8, 6))
    bars = plt.barh(range(num_categories), counts, color=color, alpha=1)

    for bar, count in zip(bars, counts):
        plt.text(bar.get_width() - 5, bar.get_y() + bar.get_height()/2, str(count), va='center', ha='right', color='white', fontweight='bold')
        
    plt.ylabel('Categories')
    plt.xlabel('Number of Images')
    plt.yticks(range(num_categories), categories)
    plt.title(f'Distribution of Images in {dataset_name} Dataset')
    plt.tight_layout()
    plt.show()

plot_statistics('Training Set', train_counts, 'blue')
plot_statistics('Validation Set', validation_counts, 'purple')
plot_statistics('Test Set', test_counts, 'red')

# %% [markdown]
# - We count the images of each category in each folder and plot the distribution.
# - We see that there are **minor deviations** the number of samples of each category in the train dataset and a bit **more in the validation dataset**.

# %% [markdown]
# ---
# #### Create Datasets

# %%
IMG_SIZE = 32
BATCH_SIZE = 64
NUM_CLASSES = len(train_counts)

train_datasets = [image_dataset_from_directory(directory, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE) for directory in train_dirs]

train_dataset = train_datasets[0]
for dataset in train_datasets[1:]:
    train_dataset = train_dataset.concatenate(dataset)

train_dataset = train_dataset.shuffle(buffer_size=1000).prefetch(buffer_size=tf.data.AUTOTUNE)
validation_dataset = image_dataset_from_directory(validation_dir, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)
test_dataset = image_dataset_from_directory(test_dir, image_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE).prefetch(buffer_size=tf.data.AUTOTUNE)

class_names = train_datasets[0].class_names
# Out:
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.
# Found 10000 files belonging to 10 classes.

# %% [markdown]
# - We define the image size of 32 x 32 x 3 and batch size of 64 and create an array with the label's names.
# - We create the train dataset by concatenating them, we **shuffle** the samples before each epoch and **prefetch** them to memory.
# - We do the same for the validation and test dataset except shuffling which is unnecessary.

# %% [markdown]
# ---
# #### Dataset Analysis

# %%
for data_batch, labels_batch in train_dataset.take(1):
    print('data batch shape:', data_batch.shape)
    print('labels batch shape:', labels_batch.shape)
# Out:
# data batch shape: (64, 32, 32, 3)
# labels batch shape: (64,)

# %% [markdown]
# - We have batches of 64 images, 32 by 32 pixels with 3 channels (RGB).
# - We also have batches of 64 labels, one for each image.

# %% [markdown]
# ---
# #### Data Augmentation

# %%
data_augmentation = keras.Sequential(
    [
        # keras.layers.RandomCrop(height=32, width=32), # This layer is commented out because it is not compatible with the current model architecture.
        keras.layers.RandomFlip("horizontal"),
        # keras.layers.RandomTranslation(0.1, 0.1), # This layer is commented out because it didn't improve the model performance.
        # keras.layers.RandomRotation(0.1), # This layer is commented out because it didn't improve the model performance.
        # keras.layers.RandomZoom(0.1), # This layer is commented out because it didn't improve the model performance.
        keras.layers.RandomContrast(0.1),
        keras.layers.RandomBrightness(0.1),
    ]
)

# %% [markdown]
# - We define a data augmentation pipeline to apply to the images.
# - **The pipeline:**
#     - Applies horizontal flipping to a random 50% of the images that go through it.
#     - Randomly adjusts the contrast of the input images by 10%.
#     - Randomly adjusts the brightness of the input images by 10%.

# %% [markdown]
# - **The following techniques were tested but the model didn't perform well:**
#     - RandomCrop: Randomly crops the images along the width and height by 10%.
#     - Randomly translates the input images along the width and height by 10%.
#     - Randomly rotates the input images by 10%.
#     - Randomly zooms the input images by 10%.
# - **We also didn't find any custom augmentation techniques that improved the model performance**.

# %% [markdown]
# ---
# #### Augmented Dataset Visualization

# %%
for images, labels in train_dataset.take(1):
    plt.figure(figsize=(32, 32))
    for i in range(len(images)):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(8, 8, i + 1)
        plt.imshow(augmented_images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i].numpy()])
        plt.axis("off")
        plt.tight_layout()
    plt.show()

# %% [markdown]
# - We print a random batch of augmented images from the train dataset along with their respective labels.
# - We see that the images are of **different categories** and are of **low resolution**, but we have **slightly more variety** in the images.

# %% [markdown]
# ---
# #### Model Architecture

# %%
inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, kernel_regularizer=regularizers.L1L2(0.00001, 0.0001), activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(filters=64, kernel_size=3, kernel_regularizer=regularizers.L1L2(0.00001, 0.0001), activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, kernel_regularizer=regularizers.L1L2(0.00001, 0.0001), activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.Conv2D(filters=256, kernel_size=3, kernel_regularizer=regularizers.L1L2(0.00001, 0.0001), activation="relu")(x)
x = layers.BatchNormalization()(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(512, activation="relu", kernel_regularizer=regularizers.L1L2(0.0001, 0.001))(x)
x = layers.Dropout(0.125)(x)
outputs = layers.Dense(NUM_CLASSES, activation="softmax", kernel_regularizer=regularizers.L1L2(0.0001, 0.001))(x)
model = models.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 3)]       0
#
#  sequential (Sequential)     (None, 32, 32, 3)         0
#
#  rescaling (Rescaling)       (None, 32, 32, 3)         0
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  batch_normalization (BatchN  (None, 30, 30, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 10, 10, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 6400)              0
#
#  dropout (Dropout)           (None, 6400)              0
#
#  dense (Dense)               (None, 512)               3277312
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 3,672,778
# Trainable params: 3,671,818
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
#  - We decided to increase the model architecture complexity compared to the previous one to try to get better results with the data augmentation.
# - Input size of 32 x 32 x 3 (RGB).
# - Data augmentation (Horizontal Flip, Contrast (+-10%), Brightness (+-10%)).
# - Normalize each pixel value in the [0, 1] interval.
# - Two convolutional layers (32 and 64 kernels each respectively).
# - Max pooling with size 2 after the second convolution results in a 14 x 14 x 64 tensor.
# - Two convolutional layers (128 and 256 kernels each).
# - Max pooling with size 2 after the fourth convolution results in a 5 x 5 x 256 tensor.
# - 3 x 3 convolutional kernel size.
# - Batch Normalization after each convolutional layer to help stabilize and accelerate learning process.
# - L1 regularization 0.00001 and L2 regularization 0.0001 on the convolutional layers.
# - Flatten the tensor to a 6400 x 1 tensor.
# - A 512 and 10 dense output layer.
# - L1 regularization 0.0001 and L2 regularization 0.001 on the 512 and 10 dense layer.
# - Dropout of 0.5 on the flatten layer and 0.125 on the 512 dense layer.
# - ReLU activation function on the convolutional and dense layers.
# - Softmax activation function on the output layer.
# - 10 output neurons, one for each category.

# %% [markdown]
# ---
# #### Model Compilation

# %%
initial_learning_rate = 0.001
optimizer = optimizers.Adam(learning_rate=initial_learning_rate)
loss_function = keras.losses.SparseCategoricalCrossentropy()

lr_scheduler = callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2, verbose=1)
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True, verbose=1)
save_best_model = callbacks.ModelCheckpoint(filepath='../models/02_model_s_data_augm_adam.h5', save_best_only=True, monitor='val_loss', verbose=1)

callbacks = [lr_scheduler, early_stopping, save_best_model]

model.compile(optimizer=optimizer,
              loss=loss_function,
              metrics=['accuracy'])

# %% [markdown]
# - Adam as the optimizer for this model with an initial learning rate of 0.001.
# - Sparse categorical cross entropy as the loss function.
# - Learning rate scheduler to lower the learning rate by 0.1 on validation loss plateau (patience of 2).
# - Early train stopping based on validation loss improvement (stops when validation loss doesn't improve for 4 straight epochs (patience of 4)).
# - Checkpoints to save the best model between each epoch based on validation loss.

# %% [markdown]
# ---
# #### Model Training
# - Training the model during 40 epochs.

# %%
history = model.fit(train_dataset,
                    validation_data=validation_dataset,
                    epochs=40,
                    callbacks=callbacks)
# Out:
# Epoch 1/40
# 628/628 [==============================] - ETA: 0s - loss: 5.1112 - accuracy: 0.4880
# Epoch 1: val_loss improved from inf to 3.42684, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 62s 96ms/step - loss: 5.1112 - accuracy: 0.4880 - val_loss: 3.4268 - val_accuracy: 0.5139 - lr: 0.0010
# Epoch 2/40
# 628/628 [==============================] - ETA: 0s - loss: 2.8330 - accuracy: 0.6357
# Epoch 2: val_loss improved from 3.42684 to 2.88782, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 66s 104ms/step - loss: 2.8330 - accuracy: 0.6357 - val_loss: 2.8878 - val_accuracy: 0.5942 - lr: 0.0010
# Epoch 3/40
# 628/628 [==============================] - ETA: 0s - loss: 2.2695 - accuracy: 0.6906
# Epoch 3: val_loss improved from 2.88782 to 2.03077, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 60s 95ms/step - loss: 2.2695 - accuracy: 0.6906 - val_loss: 2.0308 - val_accuracy: 0.7003 - lr: 0.0010
# Epoch 4/40
# 628/628 [==============================] - ETA: 0s - loss: 1.8714 - accuracy: 0.7201
# Epoch 4: val_loss improved from 2.03077 to 1.84178, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 60s 95ms/step - loss: 1.8714 - accuracy: 0.7201 - val_loss: 1.8418 - val_accuracy: 0.6939 - lr: 0.0010
# Epoch 5/40
# 628/628 [==============================] - ETA: 0s - loss: 1.6896 - accuracy: 0.7392
# Epoch 5: val_loss improved from 1.84178 to 1.74542, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 61s 96ms/step - loss: 1.6896 - accuracy: 0.7392 - val_loss: 1.7454 - val_accuracy: 0.7036 - lr: 0.0010
# Epoch 6/40
# 628/628 [==============================] - ETA: 0s - loss: 1.5859 - accuracy: 0.7562
# Epoch 6: val_loss improved from 1.74542 to 1.62368, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 65s 103ms/step - loss: 1.5859 - accuracy: 0.7562 - val_loss: 1.6237 - val_accuracy: 0.7388 - lr: 0.0010
# Epoch 7/40
# 628/628 [==============================] - ETA: 0s - loss: 1.5441 - accuracy: 0.7683
# Epoch 7: val_loss did not improve from 1.62368
# 628/628 [==============================] - 60s 94ms/step - loss: 1.5441 - accuracy: 0.7683 - val_loss: 1.6389 - val_accuracy: 0.7313 - lr: 0.0010
# Epoch 8/40
# 628/628 [==============================] - ETA: 0s - loss: 1.5169 - accuracy: 0.7770
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 8: val_loss did not improve from 1.62368
# 628/628 [==============================] - 59s 93ms/step - loss: 1.5169 - accuracy: 0.7770 - val_loss: 1.7012 - val_accuracy: 0.7179 - lr: 0.0010
# Epoch 9/40
# 628/628 [==============================] - ETA: 0s - loss: 1.2775 - accuracy: 0.8290
# Epoch 9: val_loss improved from 1.62368 to 1.19929, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 58s 92ms/step - loss: 1.2775 - accuracy: 0.8290 - val_loss: 1.1993 - val_accuracy: 0.8294 - lr: 1.0000e-04
# Epoch 10/40
# 628/628 [==============================] - ETA: 0s - loss: 1.1015 - accuracy: 0.8472
# Epoch 10: val_loss improved from 1.19929 to 1.09115, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 62s 98ms/step - loss: 1.1015 - accuracy: 0.8472 - val_loss: 1.0912 - val_accuracy: 0.8348 - lr: 1.0000e-04
# Epoch 11/40
# 628/628 [==============================] - ETA: 0s - loss: 0.9958 - accuracy: 0.8554
# Epoch 11: val_loss improved from 1.09115 to 1.01839, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 59s 93ms/step - loss: 0.9958 - accuracy: 0.8554 - val_loss: 1.0184 - val_accuracy: 0.8352 - lr: 1.0000e-04
# Epoch 12/40
# 628/628 [==============================] - ETA: 0s - loss: 0.9294 - accuracy: 0.8623
# Epoch 12: val_loss improved from 1.01839 to 0.97789, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 59s 93ms/step - loss: 0.9294 - accuracy: 0.8623 - val_loss: 0.9779 - val_accuracy: 0.8355 - lr: 1.0000e-04
# Epoch 13/40
# 628/628 [==============================] - ETA: 0s - loss: 0.8736 - accuracy: 0.8686
# Epoch 13: val_loss improved from 0.97789 to 0.93200, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 58s 92ms/step - loss: 0.8736 - accuracy: 0.8686 - val_loss: 0.9320 - val_accuracy: 0.8401 - lr: 1.0000e-04
# Epoch 14/40
# 628/628 [==============================] - ETA: 0s - loss: 0.8343 - accuracy: 0.8715
# Epoch 14: val_loss improved from 0.93200 to 0.90379, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 58s 92ms/step - loss: 0.8343 - accuracy: 0.8715 - val_loss: 0.9038 - val_accuracy: 0.8451 - lr: 1.0000e-04
# Epoch 15/40
# 628/628 [==============================] - ETA: 0s - loss: 0.8039 - accuracy: 0.8765
# Epoch 15: val_loss improved from 0.90379 to 0.87905, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 58s 92ms/step - loss: 0.8039 - accuracy: 0.8765 - val_loss: 0.8791 - val_accuracy: 0.8463 - lr: 1.0000e-04
# Epoch 16/40
# 628/628 [==============================] - ETA: 0s - loss: 0.7801 - accuracy: 0.8794
# Epoch 16: val_loss improved from 0.87905 to 0.86042, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 65s 104ms/step - loss: 0.7801 - accuracy: 0.8794 - val_loss: 0.8604 - val_accuracy: 0.8482 - lr: 1.0000e-04
# Epoch 17/40
# 628/628 [==============================] - ETA: 0s - loss: 0.7532 - accuracy: 0.8860
# Epoch 17: val_loss improved from 0.86042 to 0.84062, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 64s 101ms/step - loss: 0.7532 - accuracy: 0.8860 - val_loss: 0.8406 - val_accuracy: 0.8528 - lr: 1.0000e-04
# Epoch 18/40
# 628/628 [==============================] - ETA: 0s - loss: 0.7333 - accuracy: 0.8889
# Epoch 18: val_loss did not improve from 0.84062
# 628/628 [==============================] - 59s 94ms/step - loss: 0.7333 - accuracy: 0.8889 - val_loss: 0.8499 - val_accuracy: 0.8478 - lr: 1.0000e-04
# Epoch 19/40
# 628/628 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.8910
# Epoch 19: val_loss improved from 0.84062 to 0.82646, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 61s 97ms/step - loss: 0.7191 - accuracy: 0.8910 - val_loss: 0.8265 - val_accuracy: 0.8536 - lr: 1.0000e-04
# Epoch 20/40
# 628/628 [==============================] - ETA: 0s - loss: 0.7019 - accuracy: 0.8949
# Epoch 20: val_loss improved from 0.82646 to 0.81961, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 59s 94ms/step - loss: 0.7019 - accuracy: 0.8949 - val_loss: 0.8196 - val_accuracy: 0.8557 - lr: 1.0000e-04
# Epoch 21/40
# 628/628 [==============================] - ETA: 0s - loss: 0.6877 - accuracy: 0.8990
# Epoch 21: val_loss improved from 0.81961 to 0.81691, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 67s 105ms/step - loss: 0.6877 - accuracy: 0.8990 - val_loss: 0.8169 - val_accuracy: 0.8566 - lr: 1.0000e-04
# Epoch 22/40
# 628/628 [==============================] - ETA: 0s - loss: 0.6796 - accuracy: 0.9014
# Epoch 22: val_loss improved from 0.81691 to 0.80834, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 68s 107ms/step - loss: 0.6796 - accuracy: 0.9014 - val_loss: 0.8083 - val_accuracy: 0.8553 - lr: 1.0000e-04
# Epoch 23/40
# 628/628 [==============================] - ETA: 0s - loss: 0.6677 - accuracy: 0.9042
# Epoch 23: val_loss improved from 0.80834 to 0.80666, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 59s 93ms/step - loss: 0.6677 - accuracy: 0.9042 - val_loss: 0.8067 - val_accuracy: 0.8582 - lr: 1.0000e-04
# Epoch 24/40
# 628/628 [==============================] - ETA: 0s - loss: 0.6553 - accuracy: 0.9085
# Epoch 24: val_loss improved from 0.80666 to 0.80196, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 60s 94ms/step - loss: 0.6553 - accuracy: 0.9085 - val_loss: 0.8020 - val_accuracy: 0.8584 - lr: 1.0000e-04
# Epoch 25/40
# 628/628 [==============================] - ETA: 0s - loss: 0.6393 - accuracy: 0.9117
# Epoch 25: val_loss did not improve from 0.80196
# 628/628 [==============================] - 61s 97ms/step - loss: 0.6393 - accuracy: 0.9117 - val_loss: 0.8031 - val_accuracy: 0.8581 - lr: 1.0000e-04
# Epoch 26/40
# 628/628 [==============================] - ETA: 0s - loss: 0.6310 - accuracy: 0.9155
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 26: val_loss did not improve from 0.80196
# 628/628 [==============================] - 67s 106ms/step - loss: 0.6310 - accuracy: 0.9155 - val_loss: 0.8074 - val_accuracy: 0.8560 - lr: 1.0000e-04
# Epoch 27/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5984 - accuracy: 0.9246
# Epoch 27: val_loss improved from 0.80196 to 0.77980, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 69s 109ms/step - loss: 0.5984 - accuracy: 0.9246 - val_loss: 0.7798 - val_accuracy: 0.8631 - lr: 1.0000e-05
# Epoch 28/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5807 - accuracy: 0.9281
# Epoch 28: val_loss improved from 0.77980 to 0.77214, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 59s 94ms/step - loss: 0.5807 - accuracy: 0.9281 - val_loss: 0.7721 - val_accuracy: 0.8641 - lr: 1.0000e-05
# Epoch 29/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5745 - accuracy: 0.9297
# Epoch 29: val_loss improved from 0.77214 to 0.76480, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 61s 96ms/step - loss: 0.5745 - accuracy: 0.9297 - val_loss: 0.7648 - val_accuracy: 0.8641 - lr: 1.0000e-05
# Epoch 30/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5658 - accuracy: 0.9300
# Epoch 30: val_loss improved from 0.76480 to 0.76024, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 68s 107ms/step - loss: 0.5658 - accuracy: 0.9300 - val_loss: 0.7602 - val_accuracy: 0.8637 - lr: 1.0000e-05
# Epoch 31/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5583 - accuracy: 0.9337
# Epoch 31: val_loss improved from 0.76024 to 0.75394, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 65s 104ms/step - loss: 0.5583 - accuracy: 0.9337 - val_loss: 0.7539 - val_accuracy: 0.8636 - lr: 1.0000e-05
# Epoch 32/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5526 - accuracy: 0.9330
# Epoch 32: val_loss improved from 0.75394 to 0.74896, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 69s 109ms/step - loss: 0.5526 - accuracy: 0.9330 - val_loss: 0.7490 - val_accuracy: 0.8660 - lr: 1.0000e-05
# Epoch 33/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5453 - accuracy: 0.9347
# Epoch 33: val_loss improved from 0.74896 to 0.74670, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 59s 94ms/step - loss: 0.5453 - accuracy: 0.9347 - val_loss: 0.7467 - val_accuracy: 0.8641 - lr: 1.0000e-05
# Epoch 34/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5422 - accuracy: 0.9333
# Epoch 34: val_loss improved from 0.74670 to 0.74216, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 64s 102ms/step - loss: 0.5422 - accuracy: 0.9333 - val_loss: 0.7422 - val_accuracy: 0.8657 - lr: 1.0000e-05
# Epoch 35/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5389 - accuracy: 0.9343
# Epoch 35: val_loss improved from 0.74216 to 0.73746, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 62s 98ms/step - loss: 0.5389 - accuracy: 0.9343 - val_loss: 0.7375 - val_accuracy: 0.8644 - lr: 1.0000e-05
# Epoch 36/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5342 - accuracy: 0.9359
# Epoch 36: val_loss improved from 0.73746 to 0.73624, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 65s 104ms/step - loss: 0.5342 - accuracy: 0.9359 - val_loss: 0.7362 - val_accuracy: 0.8647 - lr: 1.0000e-05
# Epoch 37/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5285 - accuracy: 0.9359
# Epoch 37: val_loss improved from 0.73624 to 0.73234, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 63s 100ms/step - loss: 0.5285 - accuracy: 0.9359 - val_loss: 0.7323 - val_accuracy: 0.8654 - lr: 1.0000e-05
# Epoch 38/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5248 - accuracy: 0.9354
# Epoch 38: val_loss improved from 0.73234 to 0.73042, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 64s 102ms/step - loss: 0.5248 - accuracy: 0.9354 - val_loss: 0.7304 - val_accuracy: 0.8658 - lr: 1.0000e-05
# Epoch 39/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5227 - accuracy: 0.9365
# Epoch 39: val_loss improved from 0.73042 to 0.72718, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 60s 95ms/step - loss: 0.5227 - accuracy: 0.9365 - val_loss: 0.7272 - val_accuracy: 0.8660 - lr: 1.0000e-05
# Epoch 40/40
# 628/628 [==============================] - ETA: 0s - loss: 0.5191 - accuracy: 0.9367
# Epoch 40: val_loss improved from 0.72718 to 0.72563, saving model to ../models/02_model_s_data_augm_adam.h5
# 628/628 [==============================] - 63s 99ms/step - loss: 0.5191 - accuracy: 0.9367 - val_loss: 0.7256 - val_accuracy: 0.8657 - lr: 1.0000e-05

# %% [markdown]
# ---
# #### Save Model History

# %%
with open("../history/02_model_s_data_augm_adam.pkl", "wb") as file:
    pickle.dump(history.history, file)

# %% [markdown]
# ---
# #### Model Evaluation

# %%
val_loss, val_acc = model.evaluate(validation_dataset)
print(f'Model Validation Loss: {val_loss:.2%}')
print(f'Model Validation Accuracy: {val_acc:.2%}')
# Out:
# 157/157 [==============================] - 4s 26ms/step - loss: 0.7256 - accuracy: 0.8657
# Model Validation Loss: 72.56%
# Model Validation Accuracy: 86.57%

# %% [markdown]
# ---
# #### Model Training Visualization

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# - We see that the model begins overfitting after 11 epochs.
# - The validation accuracy stops improving significantly after the 11th epoch while the training accuracy keeps improving.
# - The validation loss stops improving significantly after the 13th epoch while the training loss keeps improving.
# - The validation loss improves slightly when the learning rate changes to 0.00001 on the 27th epoch.
# - The validation loss keeps improving throughout the training despite the small improvements.
# - However, the best model is saved on the 40th epoch.

# %% [markdown]
# ---
# #### Model Testing

# %%
test_labels = []
test_predictions = []
test_probabilities = []

for images, labels in test_dataset:
    test_labels.extend(labels.numpy())
    predictions = model.predict(images)
    test_predictions.extend(np.argmax(predictions, axis=-1))
    test_probabilities.extend(predictions)

test_labels = np.array(test_labels)
test_predictions = np.array(test_predictions)
test_probabilities = np.array(test_probabilities)
# Out:
# 2/2 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 68ms/step

# %% [markdown]
# ---
# #### Confusion Matrix

# %%
cm = confusion_matrix(test_labels, test_predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues, xticks_rotation=90)
plt.show()

# %% [markdown]
# - Looking at the confusion matrix, we see that the model has some trouble distinguishing between some categories.
# - The model has a hard time distinguishing between the categories 003_cat and 005_dog.
# - The model also has a hard time distinguishing between some other categories but the error is not as significant.
# - The model has an acceptable performance on the categories 000_airplane, 001_automobile, 006_frog, 007_horse, 008_ship and 009_truck.

# %% [markdown]
# ---
# #### ROC Curve Analysis

# %%
test_labels_bin = label_binarize(test_labels, classes=range(NUM_CLASSES))

false_positive_rate = dict()
true_positive_rate = dict()
roc_auc = dict()

for i in range(NUM_CLASSES):
    false_positive_rate[i], true_positive_rate[i], _ = roc_curve(test_labels_bin[:, i], test_probabilities[:, i])
    roc_auc[i] = auc(false_positive_rate[i], true_positive_rate[i])

plt.figure(figsize=(10, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'blue', 'green', 'red', 'purple', 'brown', 'pink', 'grey'])
for i, color in zip(range(NUM_CLASSES), colors):
    plt.plot(false_positive_rate[i], true_positive_rate[i], color=color, lw=2, label=f'Class {class_names[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# - **A perfect AUC of 1.0 would mean that the model classifies all true positives and true negatives correctly**.
# - We see that the model has a good performance on the ROC curve for most categories.
# - The categories 003_cat, 003_bird and 005_dog have the worst AUC (Area Under Curve) performance.

# %% [markdown]
# ---
# #### Performance Metrics
# - **Accuracy** is the proportion of correctly predicted instances out of the total instances.
# - **Precision** is the ratio of true positive predictions to the total predicted positives. Macro precision calculates this for each class independently and then averages them.
# - **Weighted precision** calculates the precision for each class, then averages them, weighted by the number of true instances for each class.
# - **Recall** is the ratio of true positive predictions to the total actual positives. Macro recall calculates this for each class independently and then averages them.
# - **Weighted recall** calculates the recall for each class, then averages them, weighted by the number of true instances for each class.
# - The **F1-score** is the harmonic mean of precision and recall. Macro F1-score calculates this for each class independently and then averages them.
# - **Weighted F1-score** calculates the F1-score for each class, then averages them, weighted by the number of true instances for each class.

# %%
acc = accuracy_score(y_true =  test_labels, y_pred = test_predictions)
print(f'Accuracy : {np.round(acc*100,2)}%')
precision = precision_score(y_true =  test_labels, y_pred = test_predictions, average='macro')
print(f'Precision - Macro: {np.round(precision*100,2)}%')
recall = recall_score(y_true =  test_labels, y_pred = test_predictions, average='macro')
print(f'Recall - Macro: {np.round(recall*100,2)}%')
f1 = f1_score(y_true =  test_labels, y_pred = test_predictions, average='macro')
print(f'F1-score - Macro: {np.round(f1*100,2)}%')
precision = precision_score(y_true =  test_labels, y_pred = test_predictions, average='weighted')
print(f'Precision - Weighted: {np.round(precision*100,2)}%')
recall = recall_score(y_true =  test_labels, y_pred = test_predictions, average='weighted')
print(f'Recall - Weighted: {np.round(recall*100,2)}%')
f1 = f1_score(y_true =  test_labels, y_pred = test_predictions, average='weighted')
print(f'F1-score - Weighted: {np.round(f1*100,2)}%')
# Out:
# Accuracy : 86.4%
# Precision - Macro: 86.38%
# Recall - Macro: 86.4%
# F1-score - Macro: 86.37%
# Precision - Weighted: 86.38%
# Recall - Weighted: 86.4%
# F1-score - Weighted: 86.37%

# %% [markdown]
# - **Since the dataset is balanced, the MACRO average is a good metric to evaluate the model.**

# %% [markdown]
# # Conclusion
# - We have trained a model with data augmentation (Horizontal Flip, Contrast and Brightness), using the Sparse Categorical Cross-Entropy loss function and the Adam optimizer.
# - We experimented with various architectures, but decided to try a more complex architecture in this notebook.
#     - Different learning rates were tested; we settled for the Reduce Learning Rate on Plateau callback.
#     - Various batch sizes were explored; this size was optimal for this architecture.
#     - Multiple optimizers were evaluated; Adam was the chosen.
#     - Several regularization values were tried; these values worked best.
#     - Different dropout rates were assessed; this rate provided the best results.
#     - Various epoch counts were tested; 40 epochs were optimal.
#     - Different kernel sizes were considered; this size was most effective.
#     - Various numbers of kernels were tested; this configuration was best.
#     - Different numbers of layers were evaluated; this architecture was the chosen.
# - We opted to add Batch Normalization after each convolutional layer.
# - We used L1 and L2 regularization on both convolutional and dense layers.
# - Dropout was applied to the dense layers.
# - The model showed some difficulty distinguishing between certain categories, particularly cats and dogs.
# - Overfitting was observed after 13 epochs, but the best model was saved at the 40th epoch.
# - We evaluated the model using a confusion matrix to analyze its performance on each category.
# - We evaluated the model using ROC curves for a deeper performance analysis.
# - The model achieved an accuracy of 86.4% on the test set.
# - Performance on the test set was good, with:
#     - Macro F1-score: 86.37%
#     - Weighted F1-score: 86.37%
#     - Macro precision: 86.38%
#     - Weighted precision: 86.38%
#     - Macro recall: 86.4%
#     - Weighted recall: 86.4%
#
# ### Future Work
# - In the next phase, we will:
#     - For the next notebook, we will try feature extraction with a pre-trained model.
#     - Experiment with different architectures for the classifier.
#     - Compile the full model and test it.
